# %%
import numpy as np
import os, cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import imutils
# from preprocess import pre_processing
size = (225, 90)
db = 'THUFV'
targets = ['image', 'mask']
source = 'gass'
rate = 0.85

for target in targets:
    name = source if target == 'mask' else 'roi'
    fp = f'./all_data/{db}/{name}'
    file = sorted(os.listdir(fp), key=lambda i:str(i.split('.')[0]))

    save_train = os.path.join(f'train_data/{source}/train', target)
    save_test = os.path.join(f'train_data/{source}/test', target)
    os.makedirs(save_train, exist_ok=True)
    os.makedirs(save_test, exist_ok=True)

    trim = [10, 10, 10, 10]
    for i, f in tqdm(enumerate(file)):
        if not f.endswith('.bmp'):
            continue
        if i < len(file)*rate:
            save = save_train
        else:
            save = save_test
        dataFile = os.path.join(fp, f)
        im = cv2.imread(dataFile, 0)
#         if target == 'mask' and source == 'gass':
#             im = cv2.GaussianBlur(im, (11,11), 0)
        im = cv2.resize(im, (256, 128))
    #     s = imutils.skeletonize(im, size=(3, 3))/2
    #     s[:trim[0], :] = 0; s[-1-trim[2]:, :] = 0; s[:, :trim[3]]=0; s[:, -1-trim[1]:]=0
    #     s = (s-np.min(s))/(np.max(s)-np.min(s))
    #     break
        cv2.imwrite(os.path.join(save, f), (im).astype(np.float32))
print('Done')
# Out:
# 4512it [00:01, 2839.56it/s]
# 4513it [00:01, 2277.49it/s]
# Done

# %%
import matplotlib.pyplot as plt
plt.imshow(s)

# %%
import numpy as np
import os, cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import imutils
from pre_process import pre_processing
[h, w] = [90, 225]
db = 'data'
target = 'test'
fp = os.path.join(db, f'{target}/image')
save_train = os.path.join(f'enh/{target}', 'image')
# os.makedirs(save, exist_ok=True)
file = sorted(os.listdir(fp), key=lambda i:str(i.split('.')[0]))
trim = [10, 10, 10, 10]
for i, f in tqdm(enumerate(file)):
    if not f.endswith('bmp'):
        continue
    dataFile = os.path.join(fp, f)
    im = cv2.imread(dataFile, 0)
    s = pre_processing(im)*255
#     break
    cv2.imwrite(os.path.join(save_train, f), s)
#     break
# Out:
# 1800it [03:22,  8.88it/s]

# %%
fp = os.path.join(db, 'gass')
dataFile = os.path.join('./data/mask', f)
s = cv2.imread(dataFile, 0)

# %%
os.path.join(save_train, f)
# Out:
# 'enh/train/image/001_1_1_01.bmp'

# %%
os.path.join(save_train, f)
# Out:
# 'enh/train/image/mask'

# %%
plt.figure(dpi=150)
i = cv2.imread(os.path.join(save, f))
plt.axis('off')
ps = np.argwhere(s>0)
plt.scatter(ps[:, 1], ps[:, 0], s=5)
plt.imshow(im, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e0c4613c8a51> in <module>
#       1 plt.figure(dpi=150)
# ----> 2 i = cv2.imread(os.path.join(save, f))
#       3 plt.axis('off')
#       4 ps = np.argwhere(s>0)
#       5 plt.scatter(ps[:, 1], ps[:, 0], s=5)
#
# NameError: name 'save' is not defined

# %%
plt.figure(dpi=150)
plt.imshow((s).astype(np.float32), cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 127.5, -0.5)

# %%
plt.figure(dpi=150)
plt.imshow(s, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 255.5, 127.5, -0.5)

# %%
im.shape
# Out:
# (242, 602)
